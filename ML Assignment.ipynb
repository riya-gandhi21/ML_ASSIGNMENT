# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('nifty_500.csv')

# %%
df.head(10)
# Out:
#                            Company Name      Symbol                Industry  \
# 0                         3M India Ltd.     3MINDIA             Diversified
# 1                      Aarti Drugs Ltd.  AARTIDRUGS              Healthcare
# 2                 Aavas Financiers Ltd.       AAVAS      Financial Services
# 3                        ABB India Ltd.         ABB           Capital Goods
# 4                     Abbott India Ltd.  ABBOTINDIA              Healthcare
# 5             Aditya Birla Capital Ltd.   ABCAPITAL      Financial Services
# 6  Aditya Birla Fashion and Retail Ltd.       ABFRL       Consumer Services
# 7        Aditya Birla Sun Life AMC Ltd.     ABSLAMC      Financial Services
# 8                              ACC Ltd.         ACC  Construction Materials
# 9                Adani Enterprises Ltd.    ADANIENT         Metals & Mining
#
#   Series      Open      High       Low  Previous Close  Last Traded Price  \
# 0     EQ  21950.00  21999.00  21126.05        21854.05           21575.00
# 1     EQ    400.50    401.80    394.10          403.85             400.00
# 2     EQ   1997.10   2004.05   1894.50         2015.45            1943.15
# 3     EQ   2260.35   2311.50   2260.35         2300.90            2280.00
# 4     EQ  18700.40  19200.00  18605.00        18760.40           19199.80
# 5     EQ     89.00     90.60     88.35           89.40              90.25
# 6     EQ    235.60    243.50    235.60          237.05             242.20
# 7     EQ    400.05    406.70    400.00          400.05             405.90
# 8     EQ   2122.95   2174.00   2122.95         2121.95            2171.70
# 9     EQ   2189.90   2242.00   2138.25         2190.90            2229.25
#
#     Change Percentage Change  Share Volume  Value (Indian Rupee)  \
# 0  -279.05             -1.28          4159          8.965357e+07
# 1    -3.85             -0.95         31782          1.262731e+07
# 2   -72.30             -3.59        150704          2.907728e+08
# 3   -20.90             -0.91         97053          2.210935e+08
# 4   439.40              2.34         12396          2.346770e+08
# 5     0.85              0.95       2401323          2.151826e+08
# 6     5.15              2.17       1014277          2.435482e+08
# 7     5.85              1.46         34489          1.390183e+07
# 8    49.75              2.34        284645          6.136206e+08
# 9    38.35              1.75       2141743          4.695579e+09
#
#    52 Week High  52 Week Low 365 Day Percentage Change  \
# 0      27800.00     17273.00                    -10.18
# 1        749.75       378.00                    -42.92
# 2       3340.00      1815.00                    -25.69
# 3       2487.85      1618.05                     27.25
# 4      23934.45     15514.00                     11.61
# 5        139.20        85.60                    -23.75
# 6        322.00       189.35                      9.87
# 7        722.90       375.00                         -
# 8       2589.00      1900.00                      5.32
# 9       2420.95      1332.75                     45.33
#
#   30 Day Percentage Change
# 0                     8.22
# 1                    -5.10
# 2                    -9.39
# 3                    -5.21
# 4                     5.84
# 5                   -11.57
# 6                   -12.62
# 7                    -5.09
# 8                    -3.48
# 9                     1.08

# %%
dfFinal=df[['Company Name','Previous Close','Last Traded Price']]

# %%
dfFinal
# Out:
#                                          Company Name  Previous Close  \
# 0                                       3M India Ltd.        21854.05
# 1                                    Aarti Drugs Ltd.          403.85
# 2                               Aavas Financiers Ltd.         2015.45
# 3                                      ABB India Ltd.         2300.90
# 4                                   Abbott India Ltd.        18760.40
# ..                                                ...             ...
# 496                           Zensar Technolgies Ltd.          272.10
# 497  ZF Commercial Vehicle Control Systems India Ltd.         7716.60
# 498                                       Zomato Ltd.           53.85
# 499                           Zydus Lifesciences Ltd.          357.00
# 500                               Zydus Wellness Ltd.         1636.85
#
#      Last Traded Price
# 0             21575.00
# 1               400.00
# 2              1943.15
# 3              2280.00
# 4             19199.80
# ..                 ...
# 496             270.00
# 497            7680.00
# 498              56.00
# 499             364.00
# 500            1627.00
#
# [501 rows x 3 columns]

# %%
change_perday=[]
for i in range (0,len(dfFinal)):
    val=(dfFinal.iloc[i,1]-dfFinal.iloc[i,2])/dfFinal.iloc[i,1]
    change_perday.append(val*100)

# %%
dfFinal['Change_Calc']=change_perday
# Out:
# C:\Users\prshn\AppData\Local\Temp/ipykernel_2088/3408812954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFinal['Change_Calc']=change_perday

# %%
dfFinal
# Out:
#                                  Company Name  Previous Close  \
# 337                            Oil India Ltd.          251.50
# 338        Oil & Natural Gas Corporation Ltd.          151.55
# 312  Mangalore Refinery & Petrochemicals Ltd.           90.60
# 383                  Reliance Industries Ltd.         2595.65
# 15                         Affle (India) Ltd.         1060.30
# ..                                        ...             ...
# 59                       Brightcom Group Ltd.           31.35
# 482             Vijaya Diagnostic Centre Ltd.          333.20
# 253                   Jubilant Foodworks Ltd.          512.25
# 304    Mahindra Holidays & Resorts India Ltd.          214.40
# 314                      Muthoot Finance Ltd.          976.30
#
#      Last Traded Price  Change_Calc
# 337             214.20    14.831014
# 338             131.40    13.295942
# 312              81.55     9.988962
# 383            2406.00     7.306455
# 15             1010.00     4.743940
# ..                 ...          ...
# 59               32.90    -4.944179
# 482             351.25    -5.417167
# 253             541.15    -5.641776
# 304             227.00    -5.876866
# 314            1039.80    -6.504148
#
# [501 rows x 4 columns]

# %%
dfFinal.sort_values(by='Change_Calc',ascending=False,inplace=True)
# Out:
# E:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
dfFinal
# Out:
#                                  Company Name  Previous Close  \
# 337                            Oil India Ltd.          251.50
# 338        Oil & Natural Gas Corporation Ltd.          151.55
# 312  Mangalore Refinery & Petrochemicals Ltd.           90.60
# 383                  Reliance Industries Ltd.         2595.65
# 15                         Affle (India) Ltd.         1060.30
# ..                                        ...             ...
# 59                       Brightcom Group Ltd.           31.35
# 482             Vijaya Diagnostic Centre Ltd.          333.20
# 253                   Jubilant Foodworks Ltd.          512.25
# 304    Mahindra Holidays & Resorts India Ltd.          214.40
# 314                      Muthoot Finance Ltd.          976.30
#
#      Last Traded Price  Change_Calc
# 337             214.20    14.831014
# 338             131.40    13.295942
# 312              81.55     9.988962
# 383            2406.00     7.306455
# 15             1010.00     4.743940
# ..                 ...          ...
# 59               32.90    -4.944179
# 482             351.25    -5.417167
# 253             541.15    -5.641776
# 304             227.00    -5.876866
# 314            1039.80    -6.504148
#
# [501 rows x 4 columns]

# %%
#Top Gainers of Day
dfFinal.head(10)
# Out:
#                                  Company Name  Previous Close  \
# 337                            Oil India Ltd.          251.50
# 338        Oil & Natural Gas Corporation Ltd.          151.55
# 312  Mangalore Refinery & Petrochemicals Ltd.           90.60
# 383                  Reliance Industries Ltd.         2595.65
# 15                         Affle (India) Ltd.         1060.30
# 455            Tube Investments of India Ltd.         1841.30
# 376             Ratnamani Metals & Tubes Ltd.         1654.40
# 479                              Vedanta Ltd.          223.00
# 417                                  SRF Ltd.         2252.20
# 410                                Sobha Ltd.          577.05
#
#      Last Traded Price  Change_Calc
# 337             214.20    14.831014
# 338             131.40    13.295942
# 312              81.55     9.988962
# 383            2406.00     7.306455
# 15             1010.00     4.743940
# 455            1758.00     4.523978
# 376            1580.00     4.497099
# 479             213.70     4.170404
# 417            2161.40     4.031614
# 410             555.00     3.821159

# %%
#Top Loosers of the Day
dfFinal.sort_values(by='Change_Calc',ascending=True,inplace=True)
dfFinal.head(10)
# Out:
# E:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                                Company Name  Previous Close  \
# 314                    Muthoot Finance Ltd.          976.30
# 304  Mahindra Holidays & Resorts India Ltd.          214.40
# 253                 Jubilant Foodworks Ltd.          512.25
# 482           Vijaya Diagnostic Centre Ltd.          333.20
# 59                     Brightcom Group Ltd.           31.35
# 136                                EPL Ltd.          149.15
# 198    Hindustan Petroleum Corporation Ltd.          217.20
# 144                       Federal Bank Ltd.           90.20
# 31   Aptus Value Housing Finance India Ltd.          281.80
# 219             IIFL Wealth Management Ltd.         1481.05
#
#      Last Traded Price  Change_Calc
# 314            1039.80    -6.504148
# 304             227.00    -5.876866
# 253             541.15    -5.641776
# 482             351.25    -5.417167
# 59               32.90    -4.944179
# 136             156.50    -4.927925
# 198             227.50    -4.742173
# 144              94.05    -4.268293
# 31              293.65    -4.205110
# 219            1543.00    -4.182843

# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\prshn\AppData\Roaming\nltk_data...
# True

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Starbucks Pickup with Amazon Go to open second location on Tuesday
# Jul-12-22 08:30AM
# Google Stock Split Coming Soon As Amazon, Shopify Lack Boost
# 08:30AM
# Why Amazon clicks with shoppers  on Prime Day or any day
# 08:25AM
# Why the U.K. Inquiry Into the Microsoft-Activision Blizzard Deal Didn't Disturb Investors
# 08:23AM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Jul-12-22',
#   '08:30AM',
#   'Starbucks Pickup with Amazon Go to open second location on Tuesday'],
#  ['AMZN',
#   'Jul-12-22',
#   '08:30AM',
#   'Google Stock Split Coming Soon As Amazon, Shopify Lack Boost'],
#  ['AMZN',
#   'Jul-12-22',
#   '08:25AM',
#   'Why Amazon clicks with shoppers  on Prime Day or any day'],
#  ['AMZN',
#   'Jul-12-22',
#   '08:23AM',
#   "Why the U.K. Inquiry Into the Microsoft-Activision Blizzard Deal Didn't Disturb Investors"],
#  ['AMZN',
#   'Jul-12-22',
#   '08:15AM',
#   '51+ Amazon Prime Day Tech Deals to Shop Right Now'],
#  ['AMZN',
#   'Jul-12-22',
#   '07:20AM',
#   'Prime Day is here  and its a prime day for you to quit using Amazon'],
#  ['AMZN', 'Jul-12-22', '07:03AM', 'No Prime Day for Walmart'],
#  ['AMZN',
#   'Jul-12-22',
#   '07:01AM',
#   'Are the Carvana Shorts in Danger of Being Crushed?'],
#  ['AMZN',
#   'Jul-12-22',
#   '06:44AM',
#   'Got $5,000? 3 Stocks to Buy and Hold for the Next 20 Years'],
#  ['AMZN',
#   'Jul-12-22',
#   '06:43AM',
#   'Amazons Cloud Unit Is Whats on Sale This Prime Day'],
#  ['AMZN',
#   'Jul-12-22',
#   '06:08AM',
#   'Amazon issued 13,000 disciplinary notices at single U.S. warehouse'],
#  ['AMZN',
#   'Jul-12-22',
#   '06:00AM',
#   'Starbucks, Amazon open second cashier-less store and cafe in NYC'],
#  ['AMZN',
#   'Jul-12-22',
#   '06:00AM',
#   'INSIGHT-Amazon issued 13,000 disciplinary notices at single U.S. warehouse'],
#  ['AMZN',
#   'Jul-12-22',
#   '05:52AM',
#   "Amazon's Recent Stock Split Hints That This Could Be a Good Week for Alphabet"],
#  ['AMZN',
#   'Jul-12-22',
#   '05:25AM',
#   'Peacock Streaming Ad Revenue Is Good News for Comcast Shareholders'],
#  ['AMZN',
#   'Jul-12-22',
#   '04:53AM',
#   'Joffre Capital Seek Financing to Gain Control of Playtika'],
#  ['AMZN',
#   'Jul-12-22',
#   '03:22AM',
#   '40+ Best Amazon Prime Day Deals of 2022: Save on Tech, Home, and Fashion'],
#  ['AMZN',
#   'Jul-12-22',
#   '03:10AM',
#   'The Best Amazon Prime Day Apple Deals of 2022'],
#  ['AMZN',
#   'Jul-12-22',
#   '12:01AM',
#   'AWS Selected as Deltas Preferred Cloud Provider'],
#  ['AMZN',
#   'Jul-11-22',
#   '08:37PM',
#   'J.P. Morgan Bullish on Amazon Stock Ahead of Prime Day'],
#  ['AMZN',
#   'Jul-11-22',
#   '07:40PM',
#   'Sales growth for Amazon Prime Day expected to slow'],
#  ['AMZN', 'Jul-11-22', '06:22PM', 'Why Amazon Stock Flopped Today'],
#  ['AMZN',
#   'Jul-11-22',
#   '06:09PM',
#   'Amazon Prime Day 2022: What time it starts, the best deals and how it works'],
#  ['AMZN',
#   'Jul-11-22',
#   '05:22PM',
#   'An influencer who earns 75% of her income from Amazon shares her all-nighter routine before Prime Day deals'],
#  ['AMZN',
#   'Jul-11-22',
#   '05:15PM',
#   'Amazon gives its smart shopping carts an upgrade and expands its checkout-free tech to a college football stadium'],
#  ['AMZN',
#   'Jul-11-22',
#   '04:52PM',
#   'Why Amazon Stock Is Down 32% So Far This Year'],
#  ['AMZN',
#   'Jul-11-22',
#   '04:22PM',
#   "These Are Amazon's 10 Best Prime Day Deals 2022: Smart TVs, Streaming Services, Apple Watches And More"],
#  ['AMZN',
#   'Jul-11-22',
#   '04:15PM',
#   'Tech and communication stocks lag, U.S. dollar index reaches 20-year highs'],
#  ['AMZN',
#   'Jul-11-22',
#   '04:09PM',
#   'Amazon Prime Day: Where to find the best deals from other retailers'],
#  ['AMZN',
#   'Jul-11-22',
#   '04:00PM',
#   'Prime Day deals go fast. Heres how to track them and get what you want'],
#  ['AMZN',
#   'Jul-11-22',
#   '03:09PM',
#   'Amazon eyes Navy Yard for new grocery store'],
#  ['AMZN',
#   'Jul-11-22',
#   '03:00PM',
#   'Better Advertising Stock: Alphabet vs. Amazon'],
#  ['AMZN', 'Jul-11-22', '02:14PM', 'Amazon sued for rent at Crossgates'],
#  ['AMZN',
#   'Jul-11-22',
#   '02:00PM',
#   'Target Is Offering 3 Days of Online Deals Starting Today'],
#  ['AMZN',
#   'Jul-11-22',
#   '12:36PM',
#   'Amazon Prime Day will be huge for deal seekers hoping to score a discount amid soaring inflation'],
#  ['AMZN',
#   'Jul-11-22',
#   '12:00PM',
#   'Amazon Prime Day to See Strong Demand, but Headwinds Remain, Analyst Says'],
#  ['AMZN', 'Jul-11-22', '11:30AM', 'Is It Too Late to Buy Amazon Stock?'],
#  ['AMZN',
#   'Jul-11-22',
#   '11:27AM',
#   'Meta, Amazon, Tesla stocks fall as tech sector under pressure'],
#  ['AMZN',
#   'Jul-11-22',
#   '11:07AM',
#   "Penny Pritzker details Chicagos 'massively vibrant' tech industry"],
#  ['AMZN',
#   'Jul-11-22',
#   '10:35AM',
#   'Mullen Shares Pop On Cargo Van Deal With Amazon Delivery Services Partner DelPack'],
#  ['AMZN',
#   'Jul-11-22',
#   '10:30AM',
#   'Is It Too Late to Buy Alphabet Before the Split?'],
#  ['AMZN',
#   'Jul-11-22',
#   '10:17AM',
#   'Market check: Nasdaq falls, U.S. dollar at highest level since 2002'],
#  ['AMZN',
#   'Jul-11-22',
#   '10:12AM',
#   "Can Worker Strike Affect Amazon's (AMZN) Prime Day Prospects?"],
#  ['AMZN',
#   'Jul-11-22',
#   '09:55AM',
#   'Market check: Stocks open lower as investors brace for earnings'],
#  ['AMZN',
#   'Jul-11-22',
#   '09:13AM',
#   'Mullen Automotive stock soars after Amazon delivery partner orders up to 600 EVs'],
#  ['AMZN',
#   'Jul-11-22',
#   '09:00AM',
#   'Investors Heavily Search Amazon.com, Inc. (AMZN): Here is What You Need to Know'],
#  ['AMZN',
#   'Jul-11-22',
#   '08:50AM',
#   'Is Snowflake Stock A Buy Or Sell Amid Software Sector Volatility?'],
#  ['AMZN',
#   'Jul-11-22',
#   '08:17AM',
#   'Tech Earnings Are Coming. 6 Reasons to Brace for Even More Pain.'],
#  ['AMZN',
#   'Jul-11-22',
#   '08:00AM',
#   'The Secret Ingredient in Stocks With Amazon-Like Growth Potential'],
#  ['AMZN', 'Jul-11-22', '07:54AM', 'Here Are the Top CEOs of 2022'],
#  ['AMZN',
#   'Jul-11-22',
#   '07:28AM',
#   'Real Employment, Fed, Inflation, Earnings Season, Holiday Shopping in July'],
#  ['AMZN',
#   'Jul-11-22',
#   '07:10AM',
#   '2 of the Best Growth Stocks to Buy if Inflation Has Peaked'],
#  ['AMZN',
#   'Jul-11-22',
#   '07:08AM',
#   'Citi sees a surprising stock market rally into year-end'],
#  ['AMZN',
#   'Jul-11-22',
#   '07:00AM',
#   '13 Amazon Prime Day Deals That Are Totally Worth It'],
#  ['AMZN',
#   'Jul-11-22',
#   '06:46AM',
#   'This Could Be the Most Defensive Cloud Stock'],
#  ['AMZN',
#   'Jul-11-22',
#   '06:30AM',
#   'Stock Split Watch: Could Regeneron Be Next?'],
#  ['AMZN',
#   'Jul-11-22',
#   '05:52AM',
#   'Why Amazon and Alphabet Stock Splits Could Pay Off Big -- in 2023'],
#  ['AMZN',
#   'Jul-11-22',
#   '01:00AM',
#   'Amazon Prime Day: How to shop top products at bargain prices'],
#  ['AMZN',
#   'Jul-11-22',
#   '12:01AM',
#   'Amazon Prime Day Gets Lots of Fanfare. What It Means for the Stock.'],
#  ['AMZN',
#   'Jul-11-22',
#   '12:00AM',
#   'Amazon banks on strong Prime Day sales extravaganza'],
#  ['AMZN', 'Jul-10-22', '11:45AM', "Better Buy: Bed Bath & Beyond vs. Kohl's"],
#  ['AMZN',
#   'Jul-10-22',
#   '11:30AM',
#   '3 Red-Hot Stocks That Could Continue to Beat the Market'],
#  ['AMZN',
#   'Jul-10-22',
#   '11:28AM',
#   "Stock market: Here's what usually happens after a 20% plunge"],
#  ['AMZN', 'Jul-10-22', '11:00AM', 'How to Make the Most of Amazon Prime Day'],
#  ['AMZN',
#   'Jul-10-22',
#   '10:01AM',
#   "UPDATE 2-German union Verdi calls for 'Prime Day' strike by Amazon workers"],
#  ['AMZN',
#   'Jul-10-22',
#   '09:59AM',
#   "German union Verdi calls for 'Prime Day' strike by Amazon workers"],
#  ['AMZN',
#   'Jul-10-22',
#   '08:00AM',
#   'Buy this, not that, on Amazon Prime Day 2022'],
#  ['AMZN',
#   'Jul-10-22',
#   '07:55AM',
#   'Better Bear Market Buy: Netflix vs. Amazon'],
#  ['AMZN',
#   'Jul-10-22',
#   '07:00AM',
#   'Pinterest Makes Moves to Maximize E-Commerce Potential'],
#  ['AMZN',
#   'Jul-10-22',
#   '05:33AM',
#   'The Stock Market Faces Next Test as Inflation Looms Over Earnings Season'],
#  ['AMZN',
#   'Jul-10-22',
#   '05:30AM',
#   'Techs Red-Hot Hiring Spree Shows Signs of Cooling'],
#  ['AMZN', 'Jul-10-22', '05:30AM', 'Is Amazon a Buy Before Prime Day?'],
#  ['AMZN',
#   'Jul-10-22',
#   '05:11AM',
#   '2 No-Brainer Warren Buffett Stocks to Buy Now and Hold Forever'],
#  ['AMZN',
#   'Jul-09-22',
#   '02:18PM',
#   "Amazon Prime Day alternatives: The best deals at Target, Best Buy, and Macy's"],
#  ['AMZN',
#   'Jul-09-22',
#   '11:41AM',
#   "These Two Retail Giants Just Might Be Inflation-Proof -- Here's Why"],
#  ['AMZN',
#   'Jul-09-22',
#   '11:24AM',
#   'Is It Too Late to Buy Kornit Digital Stock?'],
#  ['AMZN',
#   'Jul-09-22',
#   '08:25AM',
#   'Costco is dominating retail as economy slows'],
#  ['AMZN',
#   'Jul-09-22',
#   '08:00AM',
#   'Is Amazon a harbinger on labor, or an outlier?'],
#  ['AMZN',
#   'Jul-09-22',
#   '07:00AM',
#   'How to Save Big Money on Amazon Prime Day 2022'],
#  ['AMZN', 'Jul-09-22', '06:45AM', '2 E-Commerce Stocks to Watch in July'],
#  ['AMZN',
#   'Jul-08-22',
#   '10:14PM',
#   'The Top CEOs: Kudos to 24 Game-Changing Corporate Leaders'],
#  ['AMZN',
#   'Jul-08-22',
#   '09:36PM',
#   'At UPS, Tattoos Are In, Low Margins Are Out'],
#  ['AMZN',
#   'Jul-08-22',
#   '07:47PM',
#   'Amazon Prime Growth Stalls in US After Price Increase'],
#  ['AMZN', 'Jul-08-22', '07:09PM', 'Weekly Roundup'],
#  ['AMZN',
#   'Jul-08-22',
#   '05:29PM',
#   'NFL is seeking a streaming platform to host its Sunday Ticket'],
#  ['AMZN',
#   'Jul-08-22',
#   '04:53PM',
#   'Florida man charged with selling fake Cisco equipment in $1 billion scheme'],
#  ['AMZN',
#   'Jul-08-22',
#   '04:50PM',
#   'Florida man charged with selling fake Cisco equipment in $1 bln scheme'],
#  ['AMZN',
#   'Jul-08-22',
#   '04:48PM',
#   'How to save up to 50% on your grocery bill and reduce food waste'],
#  ['AMZN',
#   'Jul-08-22',
#   '04:24PM',
#   'Why Washington is failing to regulate Big Tech, according to Andrew Yang'],
#  ['AMZN',
#   'Jul-08-22',
#   '04:09PM',
#   'Stocks search for direction into the close, Treasury yields invert deeper'],
#  ['AMZN',
#   'Jul-08-22',
#   '12:23PM',
#   'Amazon Deforestation Hits Record High in New Blow to Bolsonaro'],
#  ['AMZN',
#   'Jul-08-22',
#   '12:14PM',
#   'Amazon (AMZN) Boosts Prime Day Preparations With Early Perks'],
#  ['AMZN',
#   'Jul-08-22',
#   '11:41AM',
#   'Netflix (NFLX) Adds Spatial Audio to Select Movies and Shows'],
#  ['AMZN',
#   'Jul-08-22',
#   '11:30AM',
#   'Tech Investors Should Brace for More Pain as Earnings Season Dawns'],
#  ['AMZN',
#   'Jul-08-22',
#   '11:08AM',
#   'Why GameStop Is Falling One Day After a 15% Gain'],
#  ['AMZN',
#   'Jul-08-22',
#   '10:45AM',
#   'Jeff Bezos-Linked Superyacht Wont Sail Through Rotterdam After Outcry Over Dismantling Bridge'],
#  ['AMZN',
#   'Jul-08-22',
#   '10:45AM',
#   '3 Stalwart Stocks That Could Be Safer Than Amazon'],
#  ['AMZN',
#   'Jul-08-22',
#   '10:37AM',
#   'Apparel Tops Consumer Shopping Lists for Amazon Prime\xa0Day'],
#  ['AMZN',
#   'Jul-08-22',
#   '09:57AM',
#   'Market check: Stocks fall, jobs report weighs on bond market'],
#  ['AMZN',
#   'Jul-08-22',
#   '09:46AM',
#   'Midday Movers: Upstart, Spirit, GameStop and More'],
#  ['TSLA',
#   'Jul-12-22',
#   '08:57AM',
#   'Dow Jones Futures Slide As Treasury Yields, Oil Prices Tumble On Recession Fears'],
#  ['TSLA',
#   'Jul-12-22',
#   '08:19AM',
#   'Dow Jones Futures Fall, Crude Dives After Market Rally Runs Into China Wall'],
#  ['TSLA',
#   'Jul-12-22',
#   '08:09AM',
#   'Is Warren Buffett Selling? Stock in BYD, a Tesla Rival, Is Down.'],
#  ['TSLA',
#   'Jul-12-22',
#   '07:19AM',
#   'Texas Power Grid Withstands Strain of Blistering Heat Wave'],
#  ['TSLA',
#   'Jul-12-22',
#   '06:45AM',
#   '1 Electric Vehicle Stock to Buy Hand Over Fist and 1 With Serious Red Flags'],
#  ['TSLA',
#   'Jul-12-22',
#   '06:31AM',
#   'Twitter Calls Musks Attempt to Kill $44 Billion Deal Invalid and Wrongful'],
#  ['TSLA',
#   'Jul-12-22',
#   '06:20AM',
#   'Tesla Stock Vs. BYD Stock: China EV Dives On Rumors Warren Buffett Selling Stake'],
#  ['TSLA',
#   'Jul-12-22',
#   '05:30AM',
#   'Low Inventory and EV Sales Fuel Changes in How Americans Buy Cars'],
#  ['TSLA',
#   'Jul-12-22',
#   '05:09AM',
#   'Musk Says Trump Too Much Drama, Should Sit Out 2024 Race'],
#  ['TSLA',
#   'Jul-12-22',
#   '01:00AM',
#   'Chinas Suspected IP Thieves Targeted by Twins Utah Startup'],
#  ['TSLA', 'Jul-11-22', '08:30PM', 'Tesla Rival Rivian Considers a Major Move'],
#  ['TSLA',
#   'Jul-11-22',
#   '07:02PM',
#   'Twitter Sends Letter to Elon Musk Saying Effort to Terminate Deal Invalid and Wrongful'],
#  ['TSLA',
#   'Jul-11-22',
#   '06:38PM',
#   'Fiery Explosion Hits Elon Musk Mars Rocket Test'],
#  ['TSLA', 'Jul-11-22', '05:34PM', 'Why Twitter Stock Got Crushed Today'],
#  ['TSLA',
#   'Jul-11-22',
#   '04:22PM',
#   'Twitter does have the upper hand here in legal battle versus Elon Musk: Analyst'],
#  ['TSLA',
#   'Jul-11-22',
#   '04:15PM',
#   'Tech and communication stocks lag, U.S. dollar index reaches 20-year highs'],
#  ['TSLA',
#   'Jul-11-22',
#   '04:11PM',
#   'Twitter Shares Sink, With Legal Battle Ahead as Elon Musk Walks Away'],
#  ['TSLA',
#   'Jul-11-22',
#   '03:52PM',
#   'Tesla v. Musk: How a $44B deal turned into a horror show thats just beginning'],
#  ['TSLA',
#   'Jul-11-22',
#   '03:40PM',
#   'Musks Twitter Crusade Was a Waste, But Tesla Stock Is Worth a Look'],
#  ['TSLA',
#   'Jul-11-22',
#   '03:32PM',
#   'Rivian Stock Tumbles Amid Report Of Looming Layoffs; Is RIVN Stock A Buy?'],
#  ['TSLA',
#   'Jul-11-22',
#   '03:24PM',
#   'Twitter-Elon Musk lawsuit: The burden of proof lies with Mr. Musk, attorney says'],
#  ['TSLA',
#   'Jul-11-22',
#   '03:12PM',
#   'Twitter v. Musk, Biden tries to protect abortion, Teva under attack: 3 legal stories to watch'],
#  ['TSLA',
#   'Jul-11-22',
#   '02:51PM',
#   "Musk's Tesla stock sale windfall dwarfs Twitter loss"],
#  ['TSLA',
#   'Jul-11-22',
#   '02:51PM',
#   'Top Millennial, Gen Z Stocks Shift To Energy Plays; Popular Pick Tesla Sinks Even As Musk Cancels Twitter Deal'],
#  ['TSLA',
#   'Jul-11-22',
#   '02:46PM',
#   "Musk's Tesla stock sale windfall dwarfs Twitter loss"],
#  ['TSLA',
#   'Jul-11-22',
#   '02:23PM',
#   'Twitter deal: These are the legal issues Elon Musk faces after reneging on buyout'],
#  ['TSLA',
#   'Jul-11-22',
#   '02:22PM',
#   'Tesla Is Getting Into the Used Car Business'],
#  ['TSLA',
#   'Jul-11-22',
#   '02:01PM',
#   'Stock Market Under Pressure Ahead Of CPI And Earnings; Tesla And Twitter Getting Hit Hard'],
#  ['TSLA',
#   'Jul-11-22',
#   '01:49PM',
#   "Why 'Twitter deal meltdown' is a positive for Tesla stock: Analyst"],
#  ['TSLA',
#   'Jul-11-22',
#   '01:17PM',
#   'Why Tesla, Rivian, and Lucid Stocks All Tanked Today'],
#  ['TSLA',
#   'Jul-11-22',
#   '11:40AM',
#   'PCAR vs. TSLA: Which Stock Should Value Investors Buy Now?'],
#  ['TSLA', 'Jul-11-22', '11:29AM', 'Tesla Is Facing a Big New Obstacle'],
#  ['TSLA',
#   'Jul-11-22',
#   '11:27AM',
#   'Meta, Amazon, Tesla stocks fall as tech sector under pressure'],
#  ['TSLA',
#   'Jul-11-22',
#   '11:18AM',
#   'Tesla (TSLA) Halts Giga Berlin & Shanghai to Increase Capacity'],
#  ['TSLA',
#   'Jul-11-22',
#   '11:17AM',
#   'Twitter deal: These are the legal issues Elon Musk faces after reneging on buyout'],
#  ['TSLA',
#   'Jul-11-22',
#   '11:02AM',
#   "Twitter v. Musk: Tesla CEO to fight case in court that 'does not defer to billionaires'"],
#  ['TSLA',
#   'Jul-11-22',
#   '11:00AM',
#   'These Are The 5 Best EV Stocks To Buy And Watch Now'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:52AM',
#   'Electric vehicles: What Fords Mustang Mach-E offers drivers'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:48AM',
#   'Tesla stock slides after Elon Musk terminates Twitter deal'],
#  ['TSLA', 'Jul-11-22', '10:48AM', "Don't Overlook These EV Stocks"],
#  ['TSLA',
#   'Jul-11-22',
#   '10:45AM',
#   'More Likely to 5X First: General Motors Vs Ford'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:41AM',
#   'Elon Musk gloats over collapsed Twitter deal as both sides gear up for legal fight'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:30AM',
#   "When It Comes to Twitter, I'd Rather Trade Tesla"],
#  ['TSLA',
#   'Jul-11-22',
#   '10:17AM',
#   'Market check: Nasdaq falls, U.S. dollar at highest level since 2002'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:05AM',
#   'Elon Musk dealt a huge psychological blow to Twitter: Analyst'],
#  ['TSLA',
#   'Jul-11-22',
#   '10:00AM',
#   'Twitter Stock Slumps As Board Lawyers Up, Elon Musk Walks Out On $44 Billion Takeover; Tesla Stock Slides'],
#  ['TSLA',
#   'Jul-11-22',
#   '09:55AM',
#   'Market check: Stocks open lower as investors brace for earnings'],
#  ['TSLA',
#   'Jul-11-22',
#   '09:49AM',
#   'Dow Jones Falls, Tech Stocks Dive Ahead Of Earnings Season; Elon Musk Seeks To Terminate Twitter Deal'],
#  ['TSLA',
#   'Jul-11-22',
#   '09:34AM',
#   'Musks About-Face on Twitter Sends Takeover Saga to Delaware'],
#  ['TSLA',
#   'Jul-11-22',
#   '09:30AM',
#   'Epic Musk legal battle a code red and nightmare scenario for Twitter, say analysts'],
#  ['TSLA',
#   'Jul-11-22',
#   '09:21AM',
#   'Twitter plans to sue Elon Musk over broken buyout contract'],
#  ['TSLA',
#   'Jul-11-22',
#   '08:54AM',
#   'Musk Takes Swipe at Twitter With Signature-Style Meme'],
#  ['TSLA',
#   'Jul-11-22',
#   '08:18AM',
#   'Dow Jones Futures: Market Rally Set To Fall As China Fears Return; Elon Musk-Twitter Saga Far From Over'],
#  ['TSLA',
#   'Jul-11-22',
#   '07:27AM',
#   'Tesla Rises After Musk Dumps Twitter Deal. Its What Was Supposed to Happen.'],
#  ['TSLA',
#   'Jul-11-22',
#   '07:12AM',
#   'NIO, other EV maker stocks drop after China imposes COVID-related restrictions'],
#  ['TSLA',
#   'Jul-11-22',
#   '07:08AM',
#   'Citi sees a surprising stock market rally into year-end'],
#  ['TSLA',
#   'Jul-11-22',
#   '06:47AM',
#   "2 Growth Stocks That a Pair of the World's Smartest Investors Are Buying"],
#  ['TSLA',
#   'Jul-11-22',
#   '06:00AM',
#   'Elon Musk has turned Twitter into dead money: Morning Brief'],
#  ['TSLA',
#   'Jul-11-22',
#   '05:52AM',
#   'Elon Musk starts tweeting memes about being legally forced to buy Twitter'],
#  ['TSLA',
#   'Jul-11-22',
#   '02:00AM',
#   "FOCUS-For EV battery makers, it's go small or go home"],
#  ['TSLA',
#   'Jul-11-22',
#   '01:23AM',
#   'Musk Laughs Off Twitter Lawsuit in Characteristic Meme Fashion'],
#  ['TSLA',
#   'Jul-11-22',
#   '12:37AM',
#   'Twitter Didnt Seek a Sale. Now Elon Musk Doesnt Want to Buy. Cue Strange Legal Drama.'],
#  ['TSLA',
#   'Jul-10-22',
#   '06:48PM',
#   'UPDATE 1-Twitter hires U.S. law firm Wachtell to sue Musk after pulling out of $44 bln deal - sources'],
#  ['TSLA',
#   'Jul-10-22',
#   '05:45PM',
#   'Twitter, Elon Musk hire legal heavyweights for upcoming court battle: report'],
#  ['TSLA', 'Jul-10-22', '04:57PM', 'Twitter vs. Musk:  The First Shoe Drops'],
#  ['TSLA',
#   'Jul-10-22',
#   '03:38PM',
#   'Twitter hires U.S. law firm Wachtell to sue Musk after pulling out of $44 billion deal - sources'],
#  ['TSLA',
#   'Jul-10-22',
#   '02:49PM',
#   'Twitter Assembles Legal Team to Sue Musk Over Dropped Takeover'],
#  ['TSLA',
#   'Jul-10-22',
#   '11:34AM',
#   'Elon Musks Move to Pull Out of Twitter Deal Is Bad News for the Social-Media Site'],
#  ['TSLA',
#   'Jul-10-22',
#   '11:28AM',
#   "Stock market: Here's what usually happens after a 20% plunge"],
#  ['TSLA',
#   'Jul-10-22',
#   '10:00AM',
#   "We are in a recession: Long-time bull Cathie Wood is warning investors about the big problem in today's economy. Heres 3 stocks she likes right now"],
#  ['TSLA',
#   'Jul-10-22',
#   '02:39AM',
#   'Trump Lashes Out at Elon Musk and Rotten Twitter Deal'],
#  ['TSLA', 'Jul-09-22', '08:03PM', 'Elon Musk Told Us So'],
#  ['TSLA',
#   'Jul-09-22',
#   '06:27PM',
#   'Elon Musks Twitter Deal Collided With Market and Economic Tumult'],
#  ['TSLA',
#   'Jul-09-22',
#   '04:00PM',
#   'Tim Cook Snubs Tesla and Elon Musk With a Big Rival'],
#  ['TSLA',
#   'Jul-09-22',
#   '12:47PM',
#   'How Elons bizarre Twitter takeover saga could have just been a cover for him to sell $8.5 billion in Tesla stock'],
#  ['TSLA', 'Jul-09-22', '12:26PM', 'Why Tesla Is Down Nearly 30% This Year'],
#  ['TSLA',
#   'Jul-09-22',
#   '11:57AM',
#   'IPO Edges Jannarone: Seek Out Leaders Like Allego in Rough IPO Market  Cheddar TV'],
#  ['TSLA',
#   'Jul-09-22',
#   '09:44AM',
#   'Ford Is an EV Powerhouse. Thank Jim Farley.'],
#  ['TSLA', 'Jul-09-22', '09:16AM', 'Elon Musk Embraces a Conservative Cause'],
#  ['TSLA',
#   'Jul-09-22',
#   '09:13AM',
#   'Elon Musk Becomes The Defender of a Conservative Cause'],
#  ['TSLA',
#   'Jul-09-22',
#   '07:45AM',
#   'Musk Effort to Kill Deal Leaves Twitter With Only Bad Options'],
#  ['TSLA',
#   'Jul-09-22',
#   '07:00AM',
#   "This Is Elon Musk's Best Advice for Success"],
#  ['TSLA',
#   'Jul-09-22',
#   '02:46AM',
#   'Elon Musk Seeks to Abandon $44 Billion Twitter Deal'],
#  ['TSLA',
#   'Jul-08-22',
#   '10:02PM',
#   'Ford Is an EV Powerhouse.Thank Jim Farley.'],
#  ['TSLA',
#   'Jul-08-22',
#   '09:50PM',
#   'Musk Backs Out of $44 Billion Twitter Deal Over Bot Accounts'],
#  ['TSLA',
#   'Jul-08-22',
#   '08:28PM',
#   'Tesla Stock Stands to Gain if Musk Succeeds in Ending Twitter Deal'],
#  ['TSLA',
#   'Jul-08-22',
#   '08:15PM',
#   'Elon Musk Withdraws Bid for Twitter. Get Ready for a Court Battle.'],
#  ['TSLA',
#   'Jul-08-22',
#   '07:46PM',
#   'Musk Effort to Void Twitter Buyout Sets Up Delaware Court Fight'],
#  ['TSLA',
#   'Jul-08-22',
#   '07:41PM',
#   'Elon Musk Pulls Out of $44 Billion Twitter Acquisition'],
#  ['TSLA',
#   'Jul-08-22',
#   '07:31PM',
#   'Tesla Rises Above Key Level As Musk Exits Twitter Deal; EV Maker Plans To Open U.S. Supercharger Network To Other EVs'],
#  ['TSLA',
#   'Jul-08-22',
#   '07:15PM',
#   'Twitter Shares Sink After Musk Says Hes Ending Acquisition Bid'],
#  ['TSLA',
#   'Jul-08-22',
#   '06:20PM',
#   'Tesla Shares Edge Higher After Musk Walks Away From Twitter Deal'],
#  ['TSLA',
#   'Jul-08-22',
#   '06:15PM',
#   'Digital World stock surges after Elon Musk terminates Twitter purchase'],
#  ['TSLA',
#   'Jul-08-22',
#   '05:53PM',
#   'Tesla stock heads higher in after hours after Musk ends Twitter deal'],
#  ['TSLA',
#   'Jul-08-22',
#   '05:40PM',
#   "Elon Musk says he's terminating his $44-billion Twitter buyout deal"],
#  ['TSLA',
#   'Jul-08-22',
#   '05:11PM',
#   'Dow Jones Futures: Market Rally At Make-Or-Break Point; McKesson, Tesla Among 9 Stocks Flashing Buy Signals'],
#  ['TSLA',
#   'Jul-08-22',
#   '04:58PM',
#   'Elon Musk stalling Twitter deal really isnt about the bots, analyst says'],
#  ['TSLA',
#   'Jul-08-22',
#   '04:49PM',
#   'UPDATE 1-U.S. agency to open probe into fatal Florida Tesla crash'],
#  ['TSLA', 'Jul-08-22', '04:46PM', 'Elon Musk stalls on Twitter deal'],
#  ['TSLA',
#   'Jul-08-22',
#   '04:09PM',
#   'Stocks search for direction into the close, Treasury yields invert deeper'],
#  ['GOOG',
#   'Jul-12-22',
#   '08:30AM',
#   'Google Stock Split Coming Soon As Amazon, Shopify Lack Boost'],
#  ['GOOG',
#   'Jul-12-22',
#   '08:25AM',
#   'Is Google A Buy Or Sell As Stock Split Approaches?'],
#  ['GOOG',
#   'Jul-12-22',
#   '08:15AM',
#   '51+ Amazon Prime Day Tech Deals to Shop Right Now'],
#  ['GOOG',
#   'Jul-12-22',
#   '08:00AM',
#   'Silicon Valley Bets on New Transport to Counter the Rise of Remote Work'],
#  ['GOOG',
#   'Jul-12-22',
#   '06:10AM',
#   'Tech Sell-Off: 2 Growth Stocks to Buy, and 1 to Sell'],
#  ['GOOG',
#   'Jul-12-22',
#   '05:52AM',
#   "Amazon's Recent Stock Split Hints That This Could Be a Good Week for Alphabet"],
#  ['GOOG',
#   'Jul-12-22',
#   '01:00AM',
#   'What3words: Geolocation app ask users to become shareholders'],
#  ['GOOG',
#   'Jul-11-22',
#   '04:39PM',
#   'Why Digital Realty Stock Tumbled More Than 26% in the First Half of 2022'],
#  ['GOOG',
#   'Jul-11-22',
#   '04:19PM',
#   'Is The Sun Setting On The Glory Years For Facebook And Meta Stock?'],
#  ['GOOG',
#   'Jul-11-22',
#   '04:15PM',
#   'Tech and communication stocks lag, U.S. dollar index reaches 20-year highs'],
#  ['GOOG',
#   'Jul-11-22',
#   '03:00PM',
#   'Better Advertising Stock: Alphabet vs. Amazon'],
#  ['GOOG',
#   'Jul-11-22',
#   '12:59PM',
#   'Netflix Interviewing Multiple External Candidates for New Senior Role Overseeing Ad-Supported Tier'],
#  ['GOOG',
#   'Jul-11-22',
#   '11:53AM',
#   'Meta Stock Is a Sell. Use It as a Source Of Funds, Analyst Says.'],
#  ['GOOG',
#   'Jul-11-22',
#   '11:27AM',
#   'Meta, Amazon, Tesla stocks fall as tech sector under pressure'],
#  ['GOOG',
#   'Jul-11-22',
#   '11:07AM',
#   "Penny Pritzker details Chicagos 'massively vibrant' tech industry"],
#  ['GOOG',
#   'Jul-11-22',
#   '10:30AM',
#   'Is It Too Late to Buy Alphabet Before the Split?'],
#  ['GOOG',
#   'Jul-11-22',
#   '10:17AM',
#   'Market check: Nasdaq falls, U.S. dollar at highest level since 2002'],
#  ['GOOG',
#   'Jul-11-22',
#   '09:55AM',
#   'Market check: Stocks open lower as investors brace for earnings'],
#  ['GOOG',
#   'Jul-11-22',
#   '08:50AM',
#   'Is Snowflake Stock A Buy Or Sell Amid Software Sector Volatility?'],
#  ['GOOG',
#   'Jul-11-22',
#   '08:40AM',
#   'Is Salesforce A Buy Or Sell As Software Growth Stocks Struggle?'],
#  ['GOOG', 'Jul-11-22', '07:54AM', 'Here Are the Top CEOs of 2022'],
#  ['GOOG',
#   'Jul-11-22',
#   '06:47AM',
#   "2 Growth Stocks That a Pair of the World's Smartest Investors Are Buying"],
#  ['GOOG',
#   'Jul-11-22',
#   '06:46AM',
#   'This Could Be the Most Defensive Cloud Stock'],
#  ['GOOG', 'Jul-11-22', '06:33AM', 'Expedia and Booking Are Getting Googled'],
#  ['GOOG',
#   'Jul-11-22',
#   '06:25AM',
#   'These Are The Best Robinhood Stocks To Buy Or Watch Now'],
#  ['GOOG',
#   'Jul-11-22',
#   '05:52AM',
#   'Why Amazon and Alphabet Stock Splits Could Pay Off Big -- in 2023'],
#  ['GOOG', 'Jul-11-22', '05:13AM', 'Pinterest Stock: Bull vs. Bear'],
#  ['GOOG',
#   'Jul-10-22',
#   '05:30AM',
#   'Techs Red-Hot Hiring Spree Shows Signs of Cooling'],
#  ['GOOG',
#   'Jul-10-22',
#   '04:13AM',
#   'Kenyan Presidential Candidates Pledge to Uphold Peace in Polls'],
#  ['GOOG',
#   'Jul-08-22',
#   '10:14PM',
#   'The Top CEOs: Kudos to 24 Game-Changing Corporate Leaders'],
#  ['GOOG', 'Jul-08-22', '07:09PM', 'Weekly Roundup'],
#  ['GOOG',
#   'Jul-08-22',
#   '04:35PM',
#   'Google Wants to Settle With the DoJ Over Ads, Report Says. Why One Analyst Says It Wont Happen.'],
#  ['GOOG',
#   'Jul-08-22',
#   '04:24PM',
#   'Why Washington is failing to regulate Big Tech, according to Andrew Yang'],
#  ['GOOG',
#   'Jul-08-22',
#   '04:14PM',
#   'Google With Inside Track To Win Netflix Ad Partnership, Says Analyst'],
#  ['GOOG',
#   'Jul-08-22',
#   '04:05PM',
#   'U.S. senators call for investigation into how TikTok manages user data'],
#  ['GOOG',
#   'Jul-08-22',
#   '02:12PM',
#   'Summarizing 2Q22 Internet App Data, Google Search Trends Analysis By Raymond James'],
#  ['GOOG',
#   'Jul-08-22',
#   '01:58PM',
#   'UPDATE 1-Google offers concessions to avoid U.S. antitrust lawsuit -WSJ'],
#  ['GOOG',
#   'Jul-08-22',
#   '01:31PM',
#   'BTS ARMY Birthday Celebrated by Google Search With Easter Egg That Unlocks Purple Balloons, Messages From the Group'],
#  ['GOOG',
#   'Jul-08-22',
#   '01:10PM',
#   'Google offers concessions to avoid U.S. antitrust lawsuit -WSJ'],
#  ['GOOG',
#   'Jul-08-22',
#   '12:56PM',
#   'Google in talks with regulators to head off potential antitrust lawsuit: report'],
#  ['GOOG',
#   'Jul-08-22',
#   '12:09PM',
#   'Google Offers Concessions to Fend Off U.S. Antitrust Lawsuit'],
#  ['GOOG',
#   'Jul-08-22',
#   '10:59AM',
#   "Netflixs ad tier will see 'a very strong reception' from marketers, Stagwell Global CEO says"],
#  ['GOOG',
#   'Jul-08-22',
#   '10:18AM',
#   'Market check: Stocks drift lower on strong jobs report'],
#  ['GOOG',
#   'Jul-08-22',
#   '10:02AM',
#   'Google searches for flight cancellations hit highest level since 2020'],
#  ['GOOG',
#   'Jul-08-22',
#   '09:57AM',
#   'Market check: Stocks fall, jobs report weighs on bond market'],
#  ['GOOG',
#   'Jul-08-22',
#   '09:35AM',
#   'Alphabet Stock Splits Next Week: Should Investors Buy Now?'],
#  ['GOOG',
#   'Jul-08-22',
#   '09:02AM',
#   'Nancy Pelosi Stock Portfolio: 10 Latest Stocks To Consider'],
#  ['GOOG',
#   'Jul-08-22',
#   '08:38AM',
#   'The Top Stocks to Buy With $2,500 Right Now'],
#  ['GOOG',
#   'Jul-08-22',
#   '07:30AM',
#   'GameStop Stock Is Falling. Layoffs and a CFO Change Undo Stock Split Optimism.'],
#  ['GOOG',
#   'Jul-08-22',
#   '06:30AM',
#   'GameStop Stock Is Falling. Do Investors Care More About a Stock Split or Layoffs?'],
#  ['GOOG',
#   'Jul-08-22',
#   '06:12AM',
#   'Got $5,000? 2 Tech Stocks to Buy and Hold for the Long Term'],
#  ['GOOG',
#   'Jul-07-22',
#   '07:00PM',
#   'Burning Trains Reveal Wrath of Millions Without Jobs in India'],
#  ['GOOG', 'Jul-07-22', '05:58PM', 'Why Snap Stock Is Up 14.7% This Week'],
#  ['GOOG', 'Jul-07-22', '04:58PM', "Inflation: This Time It's Different?"],
#  ['GOOG',
#   'Jul-07-22',
#   '04:15PM',
#   'Markets close in the green, energy and technology stocks among biggest gainers'],
#  ['GOOG',
#   'Jul-07-22',
#   '04:04PM',
#   'Video game developers are migrating towards ongoing live services: Analyst'],
#  ['GOOG',
#   'Jul-07-22',
#   '02:50PM',
#   'Alphabet (GOOGL) Boosts Google Photos With Pop-Up UI Update'],
#  ['GOOG',
#   'Jul-07-22',
#   '02:21PM',
#   "Yahoo Finance says 'until next time' to Emily McCormick"],
#  ['GOOG',
#   'Jul-07-22',
#   '01:36PM',
#   "Exclusive-EU antitrust regulators probing tech group AOM's video licensing policy"],
#  ['GOOG',
#   'Jul-07-22',
#   '12:06PM',
#   'Top 10 Stocks To Buy Now According To Billionaire Seth Klarman'],
#  ['GOOG',
#   'Jul-07-22',
#   '11:56AM',
#   'Americas Frontier Fund to start a brand new renaissance in tech, CEO says'],
#  ['GOOG',
#   'Jul-07-22',
#   '11:27AM',
#   'John Allisons Unio Capital Portfolio: 10 Dividend Stocks'],
#  ['GOOG',
#   'Jul-07-22',
#   '11:20AM',
#   'Abortion ruling a wake-up call for tech companies collecting location data: Expert'],
#  ['GOOG',
#   'Jul-07-22',
#   '10:58AM',
#   'YouTube Says Its TikTok Rival Is a Hit With\xa0Musicians'],
#  ['GOOG',
#   'Jul-07-22',
#   '10:21AM',
#   'Market check: Energy rebounds, Tesla stock rises, China stocks get a bid'],
#  ['GOOG',
#   'Jul-07-22',
#   '09:00AM',
#   'Tech Giants Brace for\xa0Legal Mess of Abortion Data Subpoenas'],
#  ['GOOG',
#   'Jul-07-22',
#   '08:23AM',
#   'Dow Jones Futures Rise As Key Economic Signal Rebounds; Tesla Rivals In Buy Zones'],
#  ['GOOG',
#   'Jul-07-22',
#   '08:05AM',
#   'GameStop Is Splitting Its Stock. Amazon and Google Provide Clues on What Happens Next.'],
#  ['GOOG',
#   'Jul-07-22',
#   '07:40AM',
#   "Shopify's Stock Split Is Complete, but This Is the Real Reason to Buy the Stock"],
#  ['GOOG',
#   'Jul-07-22',
#   '07:03AM',
#   'Dow Jones Futures: Fed Minutes Lift Market Rally, Microsoft Makes Key Move; Tesla Rivals Are In Buy Zones'],
#  ['GOOG',
#   'Jul-07-22',
#   '06:21AM',
#   'GameStop Stock Surges On Plans For 4-For-1 Stock Split'],
#  ['GOOG', 'Jul-07-22', '06:00AM', 'Influencers with Andy Serwer: Andrew Yang'],
#  ['GOOG',
#   'Jul-07-22',
#   '06:00AM',
#   "Aging politicians 'don't understand technology': Andrew Yang"],
#  ['GOOG',
#   'Jul-06-22',
#   '06:42PM',
#   'These 2 Tech Companies Have Made Significant Acquisitons in 2022'],
#  ['GOOG',
#   'Jul-06-22',
#   '06:24PM',
#   'Microsoft Supports Abortion Access But Is Silent on Data Privacy'],
#  ['GOOG',
#   'Jul-06-22',
#   '05:45PM',
#   'Alphabet Inc. (GOOG) Outpaces Stock Market Gains: What You Should Know'],
#  ['GOOG',
#   'Jul-06-22',
#   '05:45PM',
#   'Alphabet (GOOGL) Outpaces Stock Market Gains: What You Should Know'],
#  ['GOOG',
#   'Jul-06-22',
#   '05:39PM',
#   'Tech Firms Delete Mass Shooters Accounts, But its Not Enough'],
#  ['GOOG',
#   'Jul-06-22',
#   '04:20PM',
#   'New EU laws aim to rein in Apple, Amazon, and other Big Tech companies'],
#  ['GOOG',
#   'Jul-06-22',
#   '04:02PM',
#   'Apple Plans Extreme Sports Watch With Larger Screen, Metal Case'],
#  ['GOOG',
#   'Jul-06-22',
#   '03:50PM',
#   'Fed rate hikes will hurt the generation of new tech startups: Appian CEO'],
#  ['GOOG', 'Jul-06-22', '02:01PM', 'Amazon May Have a Big Problem In Europe'],
#  ['GOOG',
#   'Jul-06-22',
#   '01:15PM',
#   "What's Next for Pinterest and Bed Bath & Beyond?"],
#  ['GOOG',
#   'Jul-06-22',
#   '01:00PM',
#   "Alphabet's (GOOGL) Google TV to Woo Users With New Feature"],
#  ['GOOG',
#   'Jul-06-22',
#   '12:49PM',
#   'Heres Why Analysts Are Cutting Estimates for Meta and Alphabet'],
#  ['GOOG',
#   'Jul-06-22',
#   '12:43PM',
#   'Alphabet Stock Is Setting Up for a Trade Ahead of Stock Split'],
#  ['GOOG',
#   'Jul-06-22',
#   '12:27PM',
#   'How YouTube Shorts passed 2 billion monthly users, according to star influencers'],
#  ['GOOG',
#   'Jul-06-22',
#   '09:37AM',
#   'Betting\xa0Against Tech Is Finally a Winning Trade\xa0as Short Sellers Sit on $20 Billion Profit'],
#  ['GOOG',
#   'Jul-06-22',
#   '08:54AM',
#   'Meta Remains Adamant On NFT Push In Contrast With Google, Apple To Secure Its Metaverse Ambitions'],
#  ['GOOG',
#   'Jul-06-22',
#   '08:45AM',
#   "Alphabet's Stock Split Takes Effect Next Week: Here's What You Need to Know"],
#  ['GOOG',
#   'Jul-06-22',
#   '08:08AM',
#   'Dow Jones Futures Fall After Techs Lead Stock Market Rebound; Investors See End To Fed Rate Hikes'],
#  ['GOOG',
#   'Jul-06-22',
#   '07:50AM',
#   '3 Cheap Stocks Investors Should Be Buying Hand Over Fist'],
#  ['GOOG',
#   'Jul-06-22',
#   '07:03AM',
#   'Online Ad Slump Wont Be a Blip for Google, Facebook, Others'],
#  ['GOOG',
#   'Jul-06-22',
#   '06:58AM',
#   'Employers must embrace hybrid work to attract top talent'],
#  ['GOOG',
#   'Jul-05-22',
#   '09:25PM',
#   'TikToks US Data Admission Stokes Fresh Concerns With Republican FCC Member'],
#  ['GOOG',
#   'Jul-05-22',
#   '08:33PM',
#   'Alphabet vs. Apple: Which FAANG Stock Does Wall Street Like the Most?'],
#  ['GOOG',
#   'Jul-05-22',
#   '07:54PM',
#   'Why Alphabet Stock Crashed 25% in the First Half of 2022'],
#  ['GOOG',
#   'Jul-05-22',
#   '05:51PM',
#   'Big Techs Bounceback Is a Glimmer of Hope After Steep Selloff'],
#  ['GOOG',
#   'Jul-05-22',
#   '05:37PM',
#   'Why Google weighed in on a contentious Oregon offshore wind issue'],
#  ['GOOG',
#   'Jul-05-22',
#   '04:19PM',
#   'Market check: Nasdaq reverses losses as tech stocks rally']]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2022-07-12  08:30AM
# 1   AMZN  2022-07-12  08:30AM
# 2   AMZN  2022-07-12  08:25AM
# 3   AMZN  2022-07-12  08:23AM
# 4   AMZN  2022-07-12  08:15AM
#
#                                             headline    neg    neu    pos  \
# 0  Starbucks Pickup with Amazon Go to open second...  0.000  0.855  0.145
# 1  Google Stock Split Coming Soon As Amazon, Shop...  0.168  0.511  0.321
# 2  Why Amazon clicks with shoppers  on Prime Day ...  0.000  0.855  0.145
# 3  Why the U.K. Inquiry Into the Microsoft-Activi...  0.000  0.830  0.170
# 4  51+ Amazon Prime Day Tech Deals to Shop Right Now  0.000  0.841  0.159
#
#    compound
# 0    0.1779
# 1    0.2732
# 2    0.1779
# 3    0.3089
# 4    0.1779

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()

# %%
#The above code gives rise to the following chart. Notice that on some days without news headlines for any particular stock,
#there would be no sentiment score.
